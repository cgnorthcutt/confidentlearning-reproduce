# %% [markdown]
# # Script to generate CIFAR-10 benchmarking jobs

# %%
import pandas as pd
df_batch_size = pd.read_pickle('batch_sizes_df.p')

# %%
template = '''mkdir -p /home/cgn/cifar10_cl_coteaching/trial{seed}/{method}/{sparsity}_{noise}
cd /home/cgn/cifar10_cl_coteaching/trial{seed}/{method}/{sparsity}_{noise}
{{ time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py \
--coteaching --forget-rate 0.{forget_rate} --seed {seed} --batch-size {batchsize} \
--lr {lr} --epochs {epochs} --gpu {gpu} \
--train-labels "${{base}}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.{sparsity}__noise_amount__0.{noise}.json" \
--dir-train-mask "${{base}}/cifar10_noisy_labels__frac_zero_noise_rates__0_{sparsity}__noise_amount__0_{noise}/train_pruned_{method_long}/train_mask.npy" \
/datasets/datasets/cifar10/cifar10/ ; }} &> out.log
'''

gpu_rig_names = ['Pikeville', 'Richmond', 'Morehead', 'Kentucky']
keys = ['argmax', 'cj_only', 'pbc', 'pbnr', 'both']
vals = ['argmax', 'conf_joint_only', 'cl_pbc', 'cl_pbnr', 'cl_both']
sparsities = [0, 2, 4, 6]
noise_rates = [2, 4, 6]
methods = dict(zip(keys, vals))
total_gpus = 16
num_trials = 10
start_trial = 2
trials = range(start_trial, num_trials + 1)  # Trials are 1-indexed.
num_jobs = len(methods) * len(sparsities) * len(noise_rates) * len(trials)
jobs_per_gpu = int(round(num_jobs / total_gpus))
gpus_per_machine = 4
lr = 0.001
epochs = 350

counter = 0
gpu_counter = 0
for sparsity in sparsities:
    for noise in noise_rates:
        for method, method_long in methods.items():
            # Index by # (noise_amount, frac_zero_noise_rates)
            batch_size = df_batch_size[(noise / 10., sparsity / 10.)][method]
            for seed in trials:  # 1-indexed trials
                gpu_id = counter // jobs_per_gpu % gpus_per_machine
                if counter % jobs_per_gpu == 0:
                    rig_name = gpu_rig_names[gpu_counter // gpus_per_machine]
                    print('\n# Machine: {} | GPU: {}\n'.format(rig_name, gpu_id))
                    print('base="/home/cgn/cgn/confidentlearning-reproduce/cifar10"')
                    gpu_counter += 1

                print('# Job: {}'.format(counter % jobs_per_gpu + 1))
                print(template.format(
                    batchsize=batch_size,
                    lr=lr,
                    sparsity=sparsity,
                    noise=noise,
                    forget_rate=noise//2,
                    method=method,
                    method_long=method_long,
                    gpu=gpu_id,
                    epochs=epochs,
                    seed=seed,
                ))
                counter += 1
assert(counter == num_jobs)
# Out:
# # Machine: Pikeville | GPU: 0
#
# base="/home/cgn/cgn/confidentlearning-reproduce/cifar10"
# # Job: 1
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial2/argmax/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial2/argmax/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 2 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 2
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial3/argmax/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial3/argmax/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 3 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 3
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial4/argmax/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial4/argmax/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 4 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 4
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial5/argmax/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial5/argmax/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 5 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 5
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial6/argmax/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial6/argmax/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 6 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 6
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial7/argmax/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial7/argmax/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 7 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 7
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial8/argmax/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial8/argmax/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 8 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 8
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial9/argmax/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial9/argmax/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 9 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 9
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial10/argmax/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial10/argmax/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 10 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 10
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial2/cj_only/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial2/cj_only/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 2 --batch-size 450 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 11
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial3/cj_only/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial3/cj_only/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 3 --batch-size 450 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 12
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial4/cj_only/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial4/cj_only/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 4 --batch-size 450 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 13
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial5/cj_only/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial5/cj_only/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 5 --batch-size 450 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 14
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial6/cj_only/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial6/cj_only/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 6 --batch-size 450 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 15
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial7/cj_only/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial7/cj_only/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 7 --batch-size 450 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 16
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial8/cj_only/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial8/cj_only/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 8 --batch-size 450 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 17
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial9/cj_only/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial9/cj_only/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 9 --batch-size 450 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 18
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial10/cj_only/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial10/cj_only/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 10 --batch-size 450 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 19
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial2/pbc/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial2/pbc/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 2 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 20
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial3/pbc/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial3/pbc/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 3 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 21
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial4/pbc/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial4/pbc/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 4 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 22
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial5/pbc/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial5/pbc/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 5 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 23
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial6/pbc/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial6/pbc/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 6 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 24
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial7/pbc/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial7/pbc/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 7 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 25
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial8/pbc/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial8/pbc/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 8 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 26
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial9/pbc/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial9/pbc/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 9 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 27
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial10/pbc/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial10/pbc/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 10 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 28
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial2/pbnr/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial2/pbnr/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 2 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 29
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial3/pbnr/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial3/pbnr/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 3 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 30
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial4/pbnr/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial4/pbnr/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 4 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 31
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial5/pbnr/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial5/pbnr/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 5 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 32
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial6/pbnr/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial6/pbnr/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 6 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 33
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial7/pbnr/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial7/pbnr/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 7 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 34
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial8/pbnr/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial8/pbnr/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 8 --batch-size 128 --lr 0.001 --epochs 350 --gpu 0 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
#
# # Machine: Pikeville | GPU: 1
#
# base="/home/cgn/cgn/confidentlearning-reproduce/cifar10"
# # Job: 1
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial9/pbnr/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial9/pbnr/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 9 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 2
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial10/pbnr/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial10/pbnr/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 10 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 3
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial2/both/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial2/both/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 2 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 4
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial3/both/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial3/both/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 3 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 5
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial4/both/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial4/both/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 4 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 6
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial5/both/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial5/both/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 5 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 7
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial6/both/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial6/both/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 6 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 8
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial7/both/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial7/both/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 7 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 9
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial8/both/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial8/both/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 8 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 10
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial9/both/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial9/both/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 9 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 11
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial10/both/0_2
# cd /home/cgn/cifar10_cl_coteaching/trial10/both/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 10 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 12
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial2/argmax/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial2/argmax/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 2 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 13
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial3/argmax/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial3/argmax/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 3 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 14
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial4/argmax/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial4/argmax/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 4 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 15
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial5/argmax/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial5/argmax/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 5 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 16
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial6/argmax/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial6/argmax/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 6 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 17
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial7/argmax/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial7/argmax/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 7 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 18
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial8/argmax/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial8/argmax/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 8 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 19
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial9/argmax/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial9/argmax/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 9 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 20
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial10/argmax/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial10/argmax/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 10 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 21
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial2/cj_only/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial2/cj_only/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 2 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 22
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial3/cj_only/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial3/cj_only/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 3 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 23
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial4/cj_only/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial4/cj_only/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 4 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 24
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial5/cj_only/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial5/cj_only/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 5 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 25
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial6/cj_only/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial6/cj_only/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 6 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 26
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial7/cj_only/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial7/cj_only/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 7 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 27
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial8/cj_only/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial8/cj_only/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 8 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 28
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial9/cj_only/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial9/cj_only/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 9 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 29
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial10/cj_only/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial10/cj_only/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 10 --batch-size 128 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 30
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial2/pbc/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial2/pbc/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 2 --batch-size 450 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 31
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial3/pbc/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial3/pbc/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 3 --batch-size 450 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 32
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial4/pbc/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial4/pbc/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 4 --batch-size 450 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 33
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial5/pbc/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial5/pbc/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 5 --batch-size 450 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 34
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial6/pbc/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial6/pbc/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 6 --batch-size 450 --lr 0.001 --epochs 350 --gpu 1 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
#
# # Machine: Pikeville | GPU: 2
#
# base="/home/cgn/cgn/confidentlearning-reproduce/cifar10"
# # Job: 1
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial7/pbc/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial7/pbc/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 7 --batch-size 450 --lr 0.001 --epochs 350 --gpu 2 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 2
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial8/pbc/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial8/pbc/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 8 --batch-size 450 --lr 0.001 --epochs 350 --gpu 2 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 3
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial9/pbc/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial9/pbc/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 9 --batch-size 450 --lr 0.001 --epochs 350 --gpu 2 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 4
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial10/pbc/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial10/pbc/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 10 --batch-size 450 --lr 0.001 --epochs 350 --gpu 2 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 5
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial2/pbnr/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial2/pbnr/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 2 --batch-size 128 --lr 0.001 --epochs 350 --gpu 2 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 6
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial3/pbnr/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial3/pbnr/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 3 --batch-size 128 --lr 0.001 --epochs 350 --gpu 2 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 7
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial4/pbnr/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial4/pbnr/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 4 --batch-size 128 --lr 0.001 --epochs 350 --gpu 2 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 8
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial5/pbnr/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial5/pbnr/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 5 --batch-size 128 --lr 0.001 --epochs 350 --gpu 2 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 9
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial6/pbnr/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial6/pbnr/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 6 --batch-size 128 --lr 0.001 --epochs 350 --gpu 2 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 10
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial7/pbnr/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial7/pbnr/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 7 --batch-size 128 --lr 0.001 --epochs 350 --gpu 2 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 11
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial8/pbnr/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial8/pbnr/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 8 --batch-size 128 --lr 0.001 --epochs 350 --gpu 2 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 12
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial9/pbnr/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial9/pbnr/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 9 --batch-size 128 --lr 0.001 --epochs 350 --gpu 2 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 13
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial10/pbnr/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial10/pbnr/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 10 --batch-size 128 --lr 0.001 --epochs 350 --gpu 2 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 14
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial2/both/0_4
# cd /home/cgn/cifar10_cl_coteaching/trial2/both/0_4
# ...
#
# # Job: 4
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial2/pbc/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial2/pbc/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 2 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 5
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial3/pbc/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial3/pbc/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 3 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 6
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial4/pbc/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial4/pbc/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 4 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 7
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial5/pbc/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial5/pbc/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 5 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 8
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial6/pbc/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial6/pbc/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 6 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 9
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial7/pbc/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial7/pbc/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 7 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 10
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial8/pbc/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial8/pbc/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 8 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 11
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial9/pbc/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial9/pbc/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 9 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 12
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial10/pbc/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial10/pbc/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 10 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 13
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial2/pbnr/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial2/pbnr/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 2 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 14
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial3/pbnr/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial3/pbnr/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 3 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 15
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial4/pbnr/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial4/pbnr/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 4 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 16
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial5/pbnr/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial5/pbnr/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 5 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 17
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial6/pbnr/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial6/pbnr/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 6 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 18
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial7/pbnr/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial7/pbnr/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 7 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 19
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial8/pbnr/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial8/pbnr/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 8 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 20
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial9/pbnr/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial9/pbnr/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 9 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 21
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial10/pbnr/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial10/pbnr/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 10 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 22
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial2/both/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial2/both/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 2 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 23
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial3/both/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial3/both/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 3 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 24
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial4/both/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial4/both/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 4 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 25
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial5/both/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial5/both/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 5 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 26
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial6/both/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial6/both/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 6 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 27
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial7/both/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial7/both/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 7 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 28
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial8/both/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial8/both/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 8 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 29
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial9/both/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial9/both/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 9 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# # Job: 30
# mkdir -p /home/cgn/cifar10_cl_coteaching/trial10/both/6_6
# cd /home/cgn/cifar10_cl_coteaching/trial10/both/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 10 --batch-size 128 --lr 0.001 --epochs 350 --gpu 3 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
