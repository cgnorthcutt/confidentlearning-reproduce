# %% [markdown]
# # Script to generate CIFAR-10 benchmarking jobs

# %%
template = '''mkdir -p /home/cgn/cifar10_cl_coteaching/final/{method}/{sparsity}_{noise}
cd /home/cgn/cifar10_cl_coteaching/final/{method}/{sparsity}_{noise}
{{ time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.{forget_rate} --seed 1 --batch-size {batchsize} --lr {lr} --epochs 350 \
--train-labels "${{base}}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.{sparsity}__noise_amount__0.{noise}.json" --gpu {gpu} \
--dir-train-mask "${{base}}/cifar10_noisy_labels__frac_zero_noise_rates__0_{sparsity}__noise_amount__0_{noise}/train_pruned_{method_long}/train_mask.npy" \
/datasets/datasets/cifar10/cifar10/ ; }} &> out.log
'''

keys = ['argmax', 'cj_only', 'pbc', 'pbnr', 'both']
vals = ['argmax', 'conf_joint_only', 'cl_pbc', 'cl_pbnr', 'cl_both']
methods = dict(zip(keys, vals))
total_gpus = 12
num_jobs = 60
jobs_per_gpu = int(round(num_jobs / total_gpus))
gpus_per_machine = 4
batchsize = 256
lr = 0.001

counter = 0
for sparsity in [0, 2, 4, 6]:
    for noise in [2, 4, 6]:
        for method, method_long in methods.items():
            if counter % jobs_per_gpu == 0:
                print('\nbase="/home/cgn/cgn/confidentlearning-reproduce/cifar10"')
            
            print(template.format(
                batchsize=batchsize,
                lr=lr,
                sparsity=sparsity,
                noise=noise,
                forget_rate=noise//2,
                method=method,
                method_long=method_long,
                gpu=counter // jobs_per_gpu % gpus_per_machine,
            ))
            counter += 1
# Out:
# base="/home/cgn/cgn/confidentlearning-reproduce/cifar10"
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/argmax/0_2
# cd /home/cgn/cifar10_cl_coteaching/final/argmax/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --gpu 0 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/cj_only/0_2
# cd /home/cgn/cifar10_cl_coteaching/final/cj_only/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --gpu 0 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbc/0_2
# cd /home/cgn/cifar10_cl_coteaching/final/pbc/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --gpu 0 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbnr/0_2
# cd /home/cgn/cifar10_cl_coteaching/final/pbnr/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --gpu 0 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/both/0_2
# cd /home/cgn/cifar10_cl_coteaching/final/both/0_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.2.json" --gpu 0 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_2/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
#
# base="/home/cgn/cgn/confidentlearning-reproduce/cifar10"
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/argmax/0_4
# cd /home/cgn/cifar10_cl_coteaching/final/argmax/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --gpu 1 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/cj_only/0_4
# cd /home/cgn/cifar10_cl_coteaching/final/cj_only/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --gpu 1 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbc/0_4
# cd /home/cgn/cifar10_cl_coteaching/final/pbc/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --gpu 1 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbnr/0_4
# cd /home/cgn/cifar10_cl_coteaching/final/pbnr/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --gpu 1 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/both/0_4
# cd /home/cgn/cifar10_cl_coteaching/final/both/0_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.4.json" --gpu 1 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_4/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
#
# base="/home/cgn/cgn/confidentlearning-reproduce/cifar10"
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/argmax/0_6
# cd /home/cgn/cifar10_cl_coteaching/final/argmax/0_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.6.json" --gpu 2 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_6/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/cj_only/0_6
# cd /home/cgn/cifar10_cl_coteaching/final/cj_only/0_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.6.json" --gpu 2 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_6/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbc/0_6
# cd /home/cgn/cifar10_cl_coteaching/final/pbc/0_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.6.json" --gpu 2 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_6/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbnr/0_6
# cd /home/cgn/cifar10_cl_coteaching/final/pbnr/0_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.6.json" --gpu 2 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_6/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/both/0_6
# cd /home/cgn/cifar10_cl_coteaching/final/both/0_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.0__noise_amount__0.6.json" --gpu 2 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_0__noise_amount__0_6/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
#
# base="/home/cgn/cgn/confidentlearning-reproduce/cifar10"
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/argmax/2_2
# cd /home/cgn/cifar10_cl_coteaching/final/argmax/2_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.2__noise_amount__0.2.json" --gpu 3 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_2__noise_amount__0_2/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/cj_only/2_2
# cd /home/cgn/cifar10_cl_coteaching/final/cj_only/2_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.2__noise_amount__0.2.json" --gpu 3 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_2__noise_amount__0_2/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbc/2_2
# cd /home/cgn/cifar10_cl_coteaching/final/pbc/2_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.2__noise_amount__0.2.json" --gpu 3 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_2__noise_amount__0_2/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbnr/2_2
# cd /home/cgn/cifar10_cl_coteaching/final/pbnr/2_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.2__noise_amount__0.2.json" --gpu 3 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_2__noise_amount__0_2/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/both/2_2
# cd /home/cgn/cifar10_cl_coteaching/final/both/2_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.2__noise_amount__0.2.json" --gpu 3 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_2__noise_amount__0_2/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
#
# base="/home/cgn/cgn/confidentlearning-reproduce/cifar10"
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/argmax/2_4
# cd /home/cgn/cifar10_cl_coteaching/final/argmax/2_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.2__noise_amount__0.4.json" --gpu 0 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_2__noise_amount__0_4/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/cj_only/2_4
# cd /home/cgn/cifar10_cl_coteaching/final/cj_only/2_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.2__noise_amount__0.4.json" --gpu 0 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_2__noise_amount__0_4/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbc/2_4
# cd /home/cgn/cifar10_cl_coteaching/final/pbc/2_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.2__noise_amount__0.4.json" --gpu 0 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_2__noise_amount__0_4/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbnr/2_4
# cd /home/cgn/cifar10_cl_coteaching/final/pbnr/2_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.2__noise_amount__0.4.json" --gpu 0 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_2__noise_amount__0_4/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/both/2_4
# cd /home/cgn/cifar10_cl_coteaching/final/both/2_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.2__noise_amount__0.4.json" --gpu 0 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_2__noise_amount__0_4/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
#
# base="/home/cgn/cgn/confidentlearning-reproduce/cifar10"
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/argmax/2_6
# cd /home/cgn/cifar10_cl_coteaching/final/argmax/2_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.2__noise_amount__0.6.json" --gpu 1 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_2__noise_amount__0_6/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/cj_only/2_6
# cd /home/cgn/cifar10_cl_coteaching/final/cj_only/2_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.2__noise_amount__0.6.json" --gpu 1 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_2__noise_amount__0_6/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbc/2_6
# cd /home/cgn/cifar10_cl_coteaching/final/pbc/2_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.2__noise_amount__0.6.json" --gpu 1 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_2__noise_amount__0_6/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbnr/2_6
# cd /home/cgn/cifar10_cl_coteaching/final/pbnr/2_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.2__noise_amount__0.6.json" --gpu 1 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_2__noise_amount__0_6/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/both/2_6
# cd /home/cgn/cifar10_cl_coteaching/final/both/2_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.2__noise_amount__0.6.json" --gpu 1 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_2__noise_amount__0_6/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
#
# base="/home/cgn/cgn/confidentlearning-reproduce/cifar10"
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/argmax/4_2
# cd /home/cgn/cifar10_cl_coteaching/final/argmax/4_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.4__noise_amount__0.2.json" --gpu 2 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_4__noise_amount__0_2/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/cj_only/4_2
# cd /home/cgn/cifar10_cl_coteaching/final/cj_only/4_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.4__noise_amount__0.2.json" --gpu 2 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_4__noise_amount__0_2/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbc/4_2
# cd /home/cgn/cifar10_cl_coteaching/final/pbc/4_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.4__noise_amount__0.2.json" --gpu 2 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_4__noise_amount__0_2/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbnr/4_2
# cd /home/cgn/cifar10_cl_coteaching/final/pbnr/4_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.4__noise_amount__0.2.json" --gpu 2 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_4__noise_amount__0_2/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/both/4_2
# cd /home/cgn/cifar10_cl_coteaching/final/both/4_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.4__noise_amount__0.2.json" --gpu 2 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_4__noise_amount__0_2/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
#
# base="/home/cgn/cgn/confidentlearning-reproduce/cifar10"
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/argmax/4_4
# cd /home/cgn/cifar10_cl_coteaching/final/argmax/4_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.4__noise_amount__0.4.json" --gpu 3 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_4__noise_amount__0_4/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/cj_only/4_4
# cd /home/cgn/cifar10_cl_coteaching/final/cj_only/4_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.4__noise_amount__0.4.json" --gpu 3 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_4__noise_amount__0_4/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbc/4_4
# cd /home/cgn/cifar10_cl_coteaching/final/pbc/4_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.4__noise_amount__0.4.json" --gpu 3 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_4__noise_amount__0_4/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbnr/4_4
# cd /home/cgn/cifar10_cl_coteaching/final/pbnr/4_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.4__noise_amount__0.4.json" --gpu 3 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_4__noise_amount__0_4/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/both/4_4
# cd /home/cgn/cifar10_cl_coteaching/final/both/4_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.4__noise_amount__0.4.json" --gpu 3 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_4__noise_amount__0_4/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
#
# base="/home/cgn/cgn/confidentlearning-reproduce/cifar10"
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/argmax/4_6
# cd /home/cgn/cifar10_cl_coteaching/final/argmax/4_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.4__noise_amount__0.6.json" --gpu 0 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_4__noise_amount__0_6/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/cj_only/4_6
# cd /home/cgn/cifar10_cl_coteaching/final/cj_only/4_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.4__noise_amount__0.6.json" --gpu 0 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_4__noise_amount__0_6/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbc/4_6
# cd /home/cgn/cifar10_cl_coteaching/final/pbc/4_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.4__noise_amount__0.6.json" --gpu 0 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_4__noise_amount__0_6/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbnr/4_6
# cd /home/cgn/cifar10_cl_coteaching/final/pbnr/4_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.4__noise_amount__0.6.json" --gpu 0 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_4__noise_amount__0_6/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/both/4_6
# cd /home/cgn/cifar10_cl_coteaching/final/both/4_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.4__noise_amount__0.6.json" --gpu 0 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_4__noise_amount__0_6/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
#
# base="/home/cgn/cgn/confidentlearning-reproduce/cifar10"
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/argmax/6_2
# cd /home/cgn/cifar10_cl_coteaching/final/argmax/6_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.2.json" --gpu 1 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_2/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/cj_only/6_2
# cd /home/cgn/cifar10_cl_coteaching/final/cj_only/6_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.2.json" --gpu 1 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_2/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbc/6_2
# cd /home/cgn/cifar10_cl_coteaching/final/pbc/6_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.2.json" --gpu 1 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_2/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbnr/6_2
# cd /home/cgn/cifar10_cl_coteaching/final/pbnr/6_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.2.json" --gpu 1 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_2/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/both/6_2
# cd /home/cgn/cifar10_cl_coteaching/final/both/6_2
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.1 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.2.json" --gpu 1 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_2/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
#
# base="/home/cgn/cgn/confidentlearning-reproduce/cifar10"
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/argmax/6_4
# cd /home/cgn/cifar10_cl_coteaching/final/argmax/6_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.4.json" --gpu 2 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_4/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/cj_only/6_4
# cd /home/cgn/cifar10_cl_coteaching/final/cj_only/6_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.4.json" --gpu 2 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_4/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbc/6_4
# cd /home/cgn/cifar10_cl_coteaching/final/pbc/6_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.4.json" --gpu 2 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_4/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbnr/6_4
# cd /home/cgn/cifar10_cl_coteaching/final/pbnr/6_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.4.json" --gpu 2 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_4/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/both/6_4
# cd /home/cgn/cifar10_cl_coteaching/final/both/6_4
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.2 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.4.json" --gpu 2 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_4/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
#
# base="/home/cgn/cgn/confidentlearning-reproduce/cifar10"
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/argmax/6_6
# cd /home/cgn/cifar10_cl_coteaching/final/argmax/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --gpu 3 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_argmax/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/cj_only/6_6
# cd /home/cgn/cifar10_cl_coteaching/final/cj_only/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --gpu 3 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_conf_joint_only/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbc/6_6
# cd /home/cgn/cifar10_cl_coteaching/final/pbc/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --gpu 3 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbc/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/pbnr/6_6
# cd /home/cgn/cifar10_cl_coteaching/final/pbnr/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --gpu 3 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_pbnr/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
#
# mkdir -p /home/cgn/cifar10_cl_coteaching/final/both/6_6
# cd /home/cgn/cifar10_cl_coteaching/final/both/6_6
# { time python3 ~/cgn/cleanlab/examples/cifar10/cifar10_train_crossval.py --coteaching --forget-rate 0.3 --seed 1 --batch-size 256 --lr 0.001 --epochs 350 --train-labels "${base}/cifar10_noisy_labels/cifar10_noisy_labels__frac_zero_noise_rates__0.6__noise_amount__0.6.json" --gpu 3 --dir-train-mask "${base}/cifar10_noisy_labels__frac_zero_noise_rates__0_6__noise_amount__0_6/train_pruned_cl_both/train_mask.npy" /datasets/datasets/cifar10/cifar10/ ; } &> out.log
